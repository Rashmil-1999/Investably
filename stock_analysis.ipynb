# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from stocker import Stocker

# %%
microsoft = Stocker('MSFT')
# Out:
# MSFT Stocker Initialized. Data covers 1986-03-13 to 2018-03-27.

# %%
stock_history = microsoft.stock
stock_history.head()
# Out:
#         Date   Open   High   Low  Close     Volume  Ex-Dividend  Split Ratio  \
# 0 1986-03-13  25.50  29.25  25.5  28.00  3582600.0          0.0          1.0
# 1 1986-03-14  28.00  29.50  28.0  29.00  1070000.0          0.0          1.0
# 2 1986-03-17  29.00  29.75  29.0  29.50   462400.0          0.0          1.0
# 3 1986-03-18  29.50  29.75  28.5  28.75   235300.0          0.0          1.0
# 4 1986-03-19  28.75  29.00  28.0  28.25   166300.0          0.0          1.0
#
#    Adj. Open  Adj. High  Adj. Low  Adj. Close   Adj. Volume         ds  \
# 0   0.058941   0.067609  0.058941    0.064720  1.031789e+09 1986-03-13
# 1   0.064720   0.068187  0.064720    0.067031  3.081600e+08 1986-03-14
# 2   0.067031   0.068765  0.067031    0.068187  1.331712e+08 1986-03-17
# 3   0.068187   0.068765  0.065876    0.066454  6.776640e+07 1986-03-18
# 4   0.066454   0.067031  0.064720    0.065298  4.789440e+07 1986-03-19
#
#           y  Daily Change
# 0  0.064720      0.005779
# 1  0.067031      0.002311
# 2  0.068187      0.001156
# 3  0.066454     -0.001734
# 4  0.065298     -0.001156

# %%
microsoft.plot_stock()
# Out:
# stocker.py:183: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   (df['Date'] <= end_date.date())]
# stocker.py:184: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#
# /home/priyal/.local/lib/python2.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# Maximum Adj. Close = 96.77 on 2018-03-12.
# Minimum Adj. Close = 0.06 on 1986-03-24.
# Current Adj. Close = 89.47 on 2018-03-27.

# %%
microsoft.plot_stock(start_date = '2000-01-03', end_date = '2018-01-16', 
                     stats = ['Daily Change', 'Adj. Volume'], plot_type='pct')
# Out:
# Maximum Daily Change = 2.08 on 2008-10-13.
# Minimum Daily Change = -3.34 on 2017-12-04.
# Current Daily Change = -5.47 on 2018-03-27.
#
# Maximum Adj. Volume = 591052200.00 on 2006-04-28.
# Minimum Adj. Volume = 7425503.00 on 2017-11-24.
# Current Adj. Volume = 53704562.00 on 2018-03-27.

# %%
#to see the profit if we had invested in microsoft in the very beginning
microsoft.buy_and_hold(start_date='1986-03-13', end_date='2018-01-16', nshares=100)
# Out:
# MSFT Total buy and hold profit from 1986-03-13 to 2018-01-16 for 100 shares = $8829.11

# %%
#to witness the loss that we would make
microsoft.buy_and_hold(start_date='1999-01-05', end_date='2002-01-03', nshares=100)
# Out:
# MSFT Total buy and hold profit from 1999-01-05 to 2002-01-03 for 100 shares = $-56.92

# %%
microsoft.changepoint_date_analysis()
# Out:
# stocker.py:713: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   self.reset_plot()
# /home/priyal/.local/lib/python2.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# stocker.py:728: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and 'the values will not compare equal to the
# 'datetime.date'. To retain the current behavior, convert the
# 'datetime.date' to a datetime with 'pd.Timestamp'.
#   train = train.reset_index(drop=True)
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 361 2016-09-01   55.966886 -1.363753
# 169 2015-11-27   51.353167 -1.115812
# 289 2016-05-20   48.886934  0.884024
# 120 2015-09-18   41.122995  0.554914
# 506 2017-03-31   64.816957  0.540252

# %%
microsoft.changepoint_date_analysis(search = 'Microsoft profit')
# Out:
#  Top Related Queries:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-545053174bb9> in <module>()
# ----> 1 microsoft.changepoint_date_analysis(search = 'Microsoft profit')
#
# /home/priyal/Desktop/stock/stocker.py in changepoint_date_analysis(self, search)
#     784
#     785             print('\n Top Related Queries: \n')
# --> 786             print(related_queries[search]['top'].head())
#     787
#     788             print('\n Rising Related Queries: \n')
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
microsoft.changepoint_date_analysis(search = 'Microsoft Office')
# Out:
#  Top Related Queries:
#
#                    query  value
# 0             office 365    100
# 1   microsoft office 365     87
# 2  microsoft office 2016     51
# 3      microsoft windows     50
# 4            office 2016     49
#
#  Rising Related Queries:
#
#                        query  value
# 0      microsoft office 2017  56100
# 1      microsoft office 2016   3400
# 2                office 2016   3250
# 3       microsoft windows 10    450
# 4  volkswagen passenger cars    250
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-88eef364ec4d> in <module>()
# ----> 1 microsoft.changepoint_date_analysis(search = 'Microsoft Office')
#
# /home/priyal/Desktop/stock/stocker.py in changepoint_date_analysis(self, search)
#     792             trends = trends.resample('D')
#     793
# --> 794             trends = trends.reset_index(level=0)
#     795             trends = trends.rename(columns={'date': 'ds', search: 'freq'})
#     796
#
# /home/priyal/.local/lib/python2.7/site-packages/pandas/core/resample.pyc in __getattr__(self, attr)
#      99             return self[attr]
#     100
# --> 101         return object.__getattribute__(self, attr)
#     102
#     103     def __iter__(self):
#
# AttributeError: 'DatetimeIndexResampler' object has no attribute 'reset_index'
