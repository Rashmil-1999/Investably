# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from stocker import Stocker

# %%
amazon = Stocker('MSFT')
# Out:
# MSFT Stocker Initialized. Data covers 1986-03-13 to 2018-03-27.

# %%
amazon.plot_stock()
# Out:
# Maximum Adj. Close = 96.77 on 2018-03-12.
# Minimum Adj. Close = 0.06 on 1986-03-24.
# Current Adj. Close = 89.47 on 2018-03-27.
# /home/rashmil/Documents/investably/stocker.py:183: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   trim_df = df[(df['Date'] >= start_date.date()) &
# /home/rashmil/Documents/investably/stocker.py:184: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   (df['Date'] <= end_date.date())]
# /home/rashmil/anaconda3/lib/python3.6/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
amazon.plot_stock(stats=['Daily Change'])
# Out:
# /home/rashmil/Documents/investably/stocker.py:183: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   trim_df = df[(df['Date'] >= start_date.date()) &
# /home/rashmil/Documents/investably/stocker.py:184: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   (df['Date'] <= end_date.date())]
# Maximum Daily Change = 4.44 on 2018-02-06.
# Minimum Daily Change = -5.47 on 2018-03-27.
# Current Daily Change = -5.47 on 2018-03-27.

# %%
model, model_data = amazon.create_prophet_model(days=90)
# Out:
# /home/rashmil/Documents/investably/stocker.py:449: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   stock_history = self.stock[self.stock['Date'] > (self.max_date - pd.DateOffset(years = self.training_years)).date()]
# /home/rashmil/anaconda3/lib/python3.6/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# Predicted Price on 2018-06-25 = $99.90

# %%
#One way to do this is set aside some historical data as a test set and use data from further back as our training set. In the default evaluation method, we test using the past year and train on the 3 years prior to the test period.

# %%
amazon.evaluate_prediction()
# Out:
# /home/rashmil/Documents/investably/stocker.py:503: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   train = self.stock[(self.stock['Date'] < start_date.date()) &
# /home/rashmil/Documents/investably/stocker.py:504: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   (self.stock['Date'] > (start_date - pd.DateOffset(years=self.training_years)).date())]
# /home/rashmil/Documents/investably/stocker.py:507: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   test = self.stock[(self.stock['Date'] >= start_date.date()) & (self.stock['Date'] <= end_date.date())]
# /home/rashmil/anaconda3/lib/python3.6/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# Prediction Range: 2017-03-27 to 2018-03-27.
#
# Predicted price on 2018-03-24 = $81.84.
# Actual price on    2018-03-23 = $87.18.
#
# Average Absolute Error on Training Data = $1.06.
# Average Absolute Error on Testing  Data = $4.53.
#
# When the model predicted an increase, the price increased 55.31% of the time.
# When the model predicted a  decrease, the price decreased  40.00% of the time.
#
# The actual value was within the 80% confidence interval 88.00% of the time.

# %%
amazon.changepoint_prior_analysis(changepoint_priors=[0.001, 0.05, 0.1, 0.2])
# Out:
# /home/rashmil/Documents/investably/stocker.py:390: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   train = self.stock[(self.stock['Date'] > (max(self.stock['Date']) - pd.DateOffset(years=self.training_years)).date())]
# /home/rashmil/anaconda3/lib/python3.6/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# /home/rashmil/anaconda3/lib/python3.6/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# /home/rashmil/anaconda3/lib/python3.6/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# /home/rashmil/anaconda3/lib/python3.6/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()

# %%
amazon.changepoint_prior_validation(start_date='2016-01-04', end_date='2017-01-03', changepoint_priors=[0.001, 0.05, 0.1, 0.2])
# Out:
# /home/rashmil/Documents/investably/stocker.py:915: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   train = self.stock[(self.stock['Date'] > (start_date - pd.DateOffset(years=self.training_years)).date()) &
# /home/rashmil/Documents/investably/stocker.py:916: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   (self.stock['Date'] < start_date.date())]
# /home/rashmil/Documents/investably/stocker.py:919: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   test = self.stock[(self.stock['Date'] >= start_date.date()) & (self.stock['Date'] <= end_date.date())]
# /home/rashmil/anaconda3/lib/python3.6/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# Validation Range 2016-01-04 to 2017-01-03.
# /home/rashmil/anaconda3/lib/python3.6/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# /home/rashmil/anaconda3/lib/python3.6/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# /home/rashmil/anaconda3/lib/python3.6/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
#      cps  train_err  train_range  test_err  test_range
# 0  0.001   1.605824     5.170780  2.398408    5.170189
# 1  0.050   0.885413     2.874576  4.721660   11.191930
# 2  0.100   0.744495     2.480806  7.098381   22.323723
# 3  0.200   0.675742     2.281670  5.585484   35.847136

# %%
amazon.changepoint_prior_scale = 0.5

# %%
amazon.evaluate_prediction()
# Out:
# /home/rashmil/Documents/investably/stocker.py:503: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   train = self.stock[(self.stock['Date'] < start_date.date()) &
# /home/rashmil/Documents/investably/stocker.py:504: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   (self.stock['Date'] > (start_date - pd.DateOffset(years=self.training_years)).date())]
# /home/rashmil/Documents/investably/stocker.py:507: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   test = self.stock[(self.stock['Date'] >= start_date.date()) & (self.stock['Date'] <= end_date.date())]
# /home/rashmil/anaconda3/lib/python3.6/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# Prediction Range: 2017-03-27 to 2018-03-27.
#
# Predicted price on 2018-03-24 = $85.80.
# Actual price on    2018-03-23 = $87.18.
#
# Average Absolute Error on Training Data = $0.67.
# Average Absolute Error on Testing  Data = $3.62.
#
# When the model predicted an increase, the price increased 56.32% of the time.
# When the model predicted a  decrease, the price decreased  40.68% of the time.
#
# The actual value was within the 80% confidence interval 96.40% of the time.

# %%
amazon.evaluate_prediction(nshares=1000)
# Out:
# /home/rashmil/Documents/investably/stocker.py:503: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   train = self.stock[(self.stock['Date'] < start_date.date()) &
# /home/rashmil/Documents/investably/stocker.py:504: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   (self.stock['Date'] > (start_date - pd.DateOffset(years=self.training_years)).date())]
# /home/rashmil/Documents/investably/stocker.py:507: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   test = self.stock[(self.stock['Date'] >= start_date.date()) & (self.stock['Date'] <= end_date.date())]
# /home/rashmil/anaconda3/lib/python3.6/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# /home/rashmil/Documents/investably/stocker.py:618: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   test_pred_increase['pred_profit'] = prediction_profit
# You played the stock market in MSFT from 2017-03-27 to 2018-03-27 with 1000 shares.
#
# When the model predicted an increase, the price increased 56.32% of the time.
# When the model predicted a  decrease, the price decreased  40.68% of the time.
#
# The total profit using the Prophet model = $21126.12.
# The Buy and Hold strategy profit =         $23111.01.
#
# Thanks for playing the stock market!

# %%
amazon.evaluate_prediction(start_date = '2013-01-03', end_date = '2014-01-05', nshares=1000)
# Out:
# /home/rashmil/Documents/investably/stocker.py:503: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   train = self.stock[(self.stock['Date'] < start_date.date()) &
# /home/rashmil/Documents/investably/stocker.py:504: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   (self.stock['Date'] > (start_date - pd.DateOffset(years=self.training_years)).date())]
# /home/rashmil/Documents/investably/stocker.py:507: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   test = self.stock[(self.stock['Date'] >= start_date.date()) & (self.stock['Date'] <= end_date.date())]
# /home/rashmil/anaconda3/lib/python3.6/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# /home/rashmil/Documents/investably/stocker.py:618: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   test_pred_increase['pred_profit'] = prediction_profit
# You played the stock market in MSFT from 2013-01-03 to 2014-01-05 with 1000 shares.
#
# When the model predicted an increase, the price increased 49.17% of the time.
# When the model predicted a  decrease, the price decreased  40.46% of the time.
#
# The total profit using the Prophet model = $-4932.44.
# The Buy and Hold strategy profit =         $9662.43.
#
# Thanks for playing the stock market!

# %%
#predicting the future
amazon.predict_future(days=10)
# Out:
# /home/rashmil/Documents/investably/stocker.py:831: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   train = self.stock[self.stock['Date'] > (max(self.stock['Date']) - pd.DateOffset(years=self.training_years)).date()]
# /home/rashmil/anaconda3/lib/python3.6/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# /home/rashmil/Documents/investably/stocker.py:842: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   future = future[future['ds'] >= max(self.stock['Date']).date()]
# Predicted Increase:
#
#          Date   estimate    change      upper      lower
# 3  2018-03-30  92.407333  0.068856  93.779976  91.084191
# 5  2018-04-01  92.769102  0.361769  94.046092  91.426214
# 10 2018-04-06  91.820869  0.061112  93.191080  90.399804
#
# Predicted Decrease:
#
#         Date   estimate    change      upper      lower
# 1 2018-03-28  92.482998 -0.217949  93.840071  91.115029
